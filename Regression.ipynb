# %%
library(fastDummies)

# %%
bsensedata = read.csv("bsense_updated_3.csv")

# %%
bsensedata = bsensedata[2:658,]

# %%
colnames(bsensedata)
# Out:
#  [1] "Date"                           "Date.1"
#  [3] "Open_BSE"                       "High_BSE"
#  [5] "Low_BSE"                        "Close_BSE"
#  [7] "Open_NSE"                       "High_NSE"
#  [9] "Low_NSE"                        "Close_NSE"
# [11] "BSE_V1"                         "NSE_V1"
# [13] "BSE_V2"                         "NSE_V2"
# [15] "BSE_V1_speeches_avg"            "BSE_V1_speeches_avg_abs"
# [17] "BSE_V2_speeches_avg"            "BSE_V2_speeches_avg_abs"
# [19] "NSE_V1_speeches_avg"            "NSE_V1_speeches_avg_abs"
# [21] "NSE_V2_speeches_avg"            "NSE_V2_speeches_avg_abs"
# [23] "BSE_V1_mpc_avg"                 "BSE_V1_mpc_avg_abs"
# [25] "BSE_V2_mpc_avg"                 "BSE_V2_mpc_avg_abs"
# [27] "NSE_V1_mpc_avg"                 "NSE_V1_mpc_avg_abs"
# [29] "NSE_V2_mpc_avg"                 "NSE_V2_mpc_avg_abs"
# [31] "current_dummy_mpc"              "prior_dummy_mpc"
# [33] "post_dummy_mpc"                 "current_dummy_speeches"
# ...

# %%
bsensedata
# Out:
#     Date       Date.1    Open_BSE High_BSE Low_BSE  Close_BSE Open_NSE High_NSE
# 2   2019-04-02 2-Apr-19  38988.57 39121.69 38846.96 39056.65  11711.55 11729.35
# 3   2019-04-03 3-Apr-19  39167.05 39270.14 38826.56 38877.12  11735.30 11761.00
# 4   2019-04-04 4-Apr-19  38935.75 38939.35 38581.04 38684.72  11660.20 11662.55
# 5   2019-04-05 5-Apr-19  38839.52 38958.60 38701.04 38862.23  11638.40 11689.65
# 6   2019-04-08 8-Apr-19  38993.60 39041.25 38520.96 38700.53  11704.35 11710.30
# 7   2019-04-09 9-Apr-19  38730.93 38978.99 38598.72 38939.22  11612.05 11683.90
# 8   2019-04-10 10-Apr-19 38898.60 38950.45 38542.28 38585.35  11646.85 11680.05
# 9   2019-04-11 11-Apr-19 38621.58 38649.98 38460.25 38607.01  11592.55 11606.70
# 10  2019-04-12 12-Apr-19 38692.06 38818.87 38554.79 38767.11  11612.85 11657.35
# 11  2019-04-15 15-Apr-19 38805.54 38976.58 38780.08 38905.84  11667.00 11704.60
# 12  2019-04-16 16-Apr-19 39040.30 39364.34 39038.81 39275.64  11736.20 11810.95
# ...

# %%
lm.BSE_V1_speeches = lm(BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches + post_dummy_speeches, data = bsensedata)
summary(lm.BSE_V1_speeches)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.066306 -0.004965  0.000720  0.005455  0.094048
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.0014822  0.0005052  -2.934  0.00346 **
# prior_dummy_speeches    0.0008642  0.0020889   0.414  0.67922
# current_dummy_speeches -0.0017963  0.0020901  -0.859  0.39044
# post_dummy_speeches     0.0003552  0.0020889   0.170  0.86502
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.01202 on 653 degrees of freedom
# Multiple R-squared:  0.001387,	Adjusted R-squared:  -0.003201
# F-statistic: 0.3022 on 3 and 653 DF,  p-value: 0.8238

# %%
lm.BSE_V2_speeches = lm(BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches + post_dummy_speeches, data = bsensedata)
summary(lm.BSE_V2_speeches)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.079498 -0.002033  0.000311  0.002692  0.045009
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.0023767  0.0003360   7.074 3.89e-12 ***
# prior_dummy_speeches   -0.0011734  0.0013892  -0.845    0.399
# current_dummy_speeches -0.0012476  0.0013900  -0.898    0.370
# post_dummy_speeches    -0.0007871  0.0013892  -0.567    0.571
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.007992 on 653 degrees of freedom
# Multiple R-squared:  0.002953,	Adjusted R-squared:  -0.001628
# F-statistic: 0.6447 on 3 and 653 DF,  p-value: 0.5865

# %%
lm.NSE_V1_speeches = lm(NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches + post_dummy_speeches, data = bsensedata)
summary(lm.NSE_V1_speeches)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.067114 -0.004864  0.000708  0.005197  0.094131
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.0010657  0.0004860  -2.193   0.0287 *
# prior_dummy_speeches    0.0008185  0.0020094   0.407   0.6839
# current_dummy_speeches -0.0014705  0.0020106  -0.731   0.4648
# post_dummy_speeches     0.0004265  0.0020094   0.212   0.8320
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.01156 on 653 degrees of freedom
# Multiple R-squared:  0.001097,	Adjusted R-squared:  -0.003492
# F-statistic: 0.239 on 3 and 653 DF,  p-value: 0.8692

# %%
lm.NSE_V2_speeches = lm(NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches + post_dummy_speeches, data = bsensedata)
summary(lm.NSE_V2_speeches)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.093389 -0.002374  0.000397  0.003249  0.042901
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.0019419  0.0003679   5.279 1.77e-07 ***
# prior_dummy_speeches   -0.0011337  0.0015210  -0.745    0.456
# current_dummy_speeches -0.0014569  0.0015219  -0.957    0.339
# post_dummy_speeches    -0.0008276  0.0015210  -0.544    0.587
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.00875 on 653 degrees of freedom
# Multiple R-squared:  0.002839,	Adjusted R-squared:  -0.001742
# F-statistic: 0.6197 on 3 and 653 DF,  p-value: 0.6024

# %%
lm.BSE_V1_mpc = lm(BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc, data = bsensedata)
summary(lm.BSE_V1_mpc)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.066412 -0.004874  0.000609  0.005621  0.093942
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -0.0013764  0.0005085  -2.707  0.00697 **
# prior_dummy_mpc    0.0025021  0.0018819   1.330  0.18413
# current_dummy_mpc -0.0001403  0.0018958  -0.074  0.94102
# post_dummy_mpc    -0.0043995  0.0018819  -2.338  0.01970 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.01196 on 653 degrees of freedom
# Multiple R-squared:  0.01139,	Adjusted R-squared:  0.006851
# F-statistic: 2.509 on 3 and 653 DF,  p-value: 0.05786

# %%
lm.BSE_V2_mpc = lm(BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc, data = bsensedata)
summary(lm.BSE_V2_mpc)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.079209 -0.002178  0.000295  0.002869  0.045298
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       2.087e-03  3.400e-04   6.139 1.44e-09 ***
# prior_dummy_mpc   2.380e-04  1.258e-03   0.189    0.850
# current_dummy_mpc 1.431e-03  1.268e-03   1.129    0.259
# post_dummy_mpc    9.831e-05  1.258e-03   0.078    0.938
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.007995 on 653 degrees of freedom
# Multiple R-squared:  0.002191,	Adjusted R-squared:  -0.002393
# F-statistic: 0.4779 on 3 and 653 DF,  p-value: 0.6978

# %%
lm.NSE_V1_mpc = lm(NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc, data = bsensedata)
summary(lm.NSE_V1_mpc)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.067295 -0.004827  0.000724  0.005386  0.093950
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)       -0.0008845  0.0004896  -1.807   0.0713 .
# prior_dummy_mpc    0.0016219  0.0018118   0.895   0.3710
# current_dummy_mpc -0.0004233  0.0018252  -0.232   0.8167
# post_dummy_mpc    -0.0040841  0.0018118  -2.254   0.0245 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.01151 on 653 degrees of freedom
# Multiple R-squared:  0.009423,	Adjusted R-squared:  0.004872
# F-statistic: 2.071 on 3 and 653 DF,  p-value: 0.1028

# %%
lm.NSE_V2_mpc = lm(NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc, data = bsensedata)
summary(lm.NSE_V2_mpc)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.093029 -0.002344  0.000325  0.003212  0.043262
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        1.581e-03  3.720e-04   4.250 2.44e-05 ***
# prior_dummy_mpc    8.260e-04  1.376e-03   0.600    0.549
# current_dummy_mpc  1.917e-03  1.387e-03   1.383    0.167
# post_dummy_mpc    -7.442e-05  1.376e-03  -0.054    0.957
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.008746 on 653 degrees of freedom
# Multiple R-squared:  0.003866,	Adjusted R-squared:  -0.0007108
# F-statistic: 0.8447 on 3 and 653 DF,  p-value: 0.4697

# %%
lm.BSE_V1_speeches_Loughran_Polarity = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Polarity + 
                                          current_dummy_speeches*speeches_Loughran_Polarity + 
                                          post_dummy_speeches*speeches_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_Loughran_Polarity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Polarity +
#     current_dummy_speeches * speeches_Loughran_Polarity + post_dummy_speeches *
#     speeches_Loughran_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0274670 -0.0054744  0.0006582  0.0065917  0.0135248
#
# Coefficients: (2 not defined because of singularities)
#                                                     Estimate Std. Error t value
# (Intercept)                                       -0.0037727  0.0017498  -2.156
# prior_dummy_speeches                               0.0110878  0.0058468   1.896
# current_dummy_speeches                                    NA         NA      NA
# post_dummy_speeches                               -0.0007050  0.0070334  -0.100
# speeches_Loughran_Polarity                         0.0006979  0.0057641   0.121
# ...

# %%
lm.BSE_V1_speeches_Loughran_Subjectivity = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          current_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          post_dummy_speeches*speeches_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Subjectivity +
#     current_dummy_speeches * speeches_Loughran_Subjectivity +
#     post_dummy_speeches * speeches_Loughran_Subjectivity, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.027724 -0.005716  0.001652  0.005682  0.012991
#
# Coefficients: (2 not defined because of singularities)
#                                                         Estimate Std. Error
# (Intercept)                                           -0.0005822  0.0072390
# prior_dummy_speeches                                  -0.1048306  0.0739120
# current_dummy_speeches                                        NA         NA
# post_dummy_speeches                                    0.0122356  0.0393983
# speeches_Loughran_Subjectivity                        -0.0360432  0.0797215
# ...

# %%
lm.BSE_V1_speeches_NRC_Polarity = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_NRC_Polarity + 
                                          current_dummy_speeches*speeches_NRC_Polarity + 
                                          post_dummy_speeches*speeches_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_NRC_Polarity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_NRC_Polarity +
#     current_dummy_speeches * speeches_NRC_Polarity + post_dummy_speeches *
#     speeches_NRC_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0259526 -0.0059917  0.0006768  0.0060398  0.0132949
#
# Coefficients: (2 not defined because of singularities)
#                                               Estimate Std. Error t value
# (Intercept)                                  -0.007477   0.006116  -1.223
# prior_dummy_speeches                          0.007578   0.022050   0.344
# current_dummy_speeches                              NA         NA      NA
# post_dummy_speeches                           0.002669   0.017312   0.154
# speeches_NRC_Polarity                         0.008571   0.013528   0.634
# prior_dummy_speeches:speeches_NRC_Polarity    0.015396   0.069631   0.221
# ...

# %%
lm.BSE_V1_speeches_Financial_Stab_Score = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Financial_Stab_Score + 
                                          current_dummy_speeches*speeches_Financial_Stab_Score + 
                                          post_dummy_speeches*speeches_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Financial_Stab_Score +
#     current_dummy_speeches * speeches_Financial_Stab_Score +
#     post_dummy_speeches * speeches_Financial_Stab_Score, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0252152 -0.0055291  0.0002216  0.0061812  0.0131132
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                          -0.0050986  0.0018037
# prior_dummy_speeches                                  0.0128211  0.0054630
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                  -0.0077956  0.0067182
# speeches_Financial_Stab_Score                         0.0080757  0.0045891
# ...

# %%
lm.BSE_V1_speeches_Sentiword_Score = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Sentiword_Score + 
                                          current_dummy_speeches*speeches_Sentiword_Score + 
                                          post_dummy_speeches*speeches_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_Sentiword_Score)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Sentiword_Score +
#     current_dummy_speeches * speeches_Sentiword_Score + post_dummy_speeches *
#     speeches_Sentiword_Score, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.027338 -0.004967  0.001289  0.007106  0.014069
#
# Coefficients: (2 not defined because of singularities)
#                                                  Estimate Std. Error t value
# (Intercept)                                     -0.006917   0.004364  -1.585
# prior_dummy_speeches                             0.002101   0.013314   0.158
# current_dummy_speeches                                 NA         NA      NA
# post_dummy_speeches                              0.010892   0.018807   0.579
# speeches_Sentiword_Score                         0.010300   0.013122   0.785
# ...

# %%
lm.BSE_V1_speeches_Hu...Liu.Polarity = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          current_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          post_dummy_speeches*speeches_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Hu...Liu.Polarity +
#     current_dummy_speeches * speeches_Hu...Liu.Polarity + post_dummy_speeches *
#     speeches_Hu...Liu.Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0274973 -0.0054986  0.0001627  0.0070909  0.0127797
#
# Coefficients: (2 not defined because of singularities)
#                                                    Estimate Std. Error t value
# (Intercept)                                       -0.006095   0.004065  -1.499
# prior_dummy_speeches                               0.008644   0.010524   0.821
# current_dummy_speeches                                   NA         NA      NA
# post_dummy_speeches                                0.024975   0.035805   0.698
# speeches_Hu...Liu.Polarity                         0.005595   0.008830   0.634
# ...

# %%
lm.BSE_V1_speeches_Loughran_Uncertainty = lm(BSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          current_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          post_dummy_speeches*speeches_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.BSE_V1_speeches_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Uncertainty +
#     current_dummy_speeches * speeches_Loughran_Uncertainty +
#     post_dummy_speeches * speeches_Loughran_Uncertainty, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.027886 -0.005109  0.001208  0.006278  0.013443
#
# Coefficients: (2 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                          -0.002810   0.004654
# prior_dummy_speeches                                  0.001475   0.015920
# current_dummy_speeches                                      NA         NA
# post_dummy_speeches                                  -0.012090   0.013267
# speeches_Loughran_Uncertainty                        -0.148831   0.672832
# ...

# %%
lm.BSE_V2_speeches_Loughran_Polarity = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Polarity + 
                                          current_dummy_speeches*speeches_Loughran_Polarity + 
                                          post_dummy_speeches*speeches_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_Loughran_Polarity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Polarity +
#     current_dummy_speeches * speeches_Loughran_Polarity + post_dummy_speeches *
#     speeches_Loughran_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0260644 -0.0005532  0.0007680  0.0024029  0.0135407
#
# Coefficients: (2 not defined because of singularities)
#                                                     Estimate Std. Error t value
# (Intercept)                                        0.0007930  0.0014000   0.566
# prior_dummy_speeches                              -0.0014071  0.0046781  -0.301
# current_dummy_speeches                                    NA         NA      NA
# post_dummy_speeches                                0.0054044  0.0056276   0.960
# speeches_Loughran_Polarity                         0.0081636  0.0046119   1.770
# ...

# %%
lm.BSE_V2_speeches_Loughran_Subjectivity = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          current_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          post_dummy_speeches*speeches_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Subjectivity +
#     current_dummy_speeches * speeches_Loughran_Subjectivity +
#     post_dummy_speeches * speeches_Loughran_Subjectivity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0296034 -0.0008097  0.0008072  0.0030246  0.0097161
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                            0.003311   0.006316
# prior_dummy_speeches                                  -0.038885   0.064489
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                   -0.015187   0.034376
# speeches_Loughran_Subjectivity                        -0.027449   0.069558
# ...

# %%
lm.BSE_V2_speeches_NRC_Polarity = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_NRC_Polarity + 
                                          current_dummy_speeches*speeches_NRC_Polarity + 
                                          post_dummy_speeches*speeches_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_NRC_Polarity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_NRC_Polarity +
#     current_dummy_speeches * speeches_NRC_Polarity + post_dummy_speeches *
#     speeches_NRC_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0243930 -0.0018087  0.0006693  0.0030924  0.0144939
#
# Coefficients: (2 not defined because of singularities)
#                                                Estimate Std. Error t value
# (Intercept)                                  -0.0098160  0.0047118  -2.083
# prior_dummy_speeches                         -0.0003979  0.0169878  -0.023
# current_dummy_speeches                               NA         NA      NA
# post_dummy_speeches                           0.0062208  0.0133379   0.466
# speeches_NRC_Polarity                         0.0247128  0.0104222   2.371
# ...

# %%
lm.BSE_V2_speeches_Financial_Stab_Score = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Financial_Stab_Score + 
                                          current_dummy_speeches*speeches_Financial_Stab_Score + 
                                          post_dummy_speeches*speeches_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Financial_Stab_Score +
#     current_dummy_speeches * speeches_Financial_Stab_Score +
#     post_dummy_speeches * speeches_Financial_Stab_Score, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0283656 -0.0008059  0.0012345  0.0025944  0.0116082
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                           0.0002227  0.0015971
# prior_dummy_speeches                                 -0.0009285  0.0048373
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                   0.0012644  0.0059487
# speeches_Financial_Stab_Score                         0.0040262  0.0040635
# ...

# %%
lm.BSE_V2_speeches_Sentiword_Score = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Sentiword_Score + 
                                          current_dummy_speeches*speeches_Sentiword_Score + 
                                          post_dummy_speeches*speeches_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_Sentiword_Score)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Sentiword_Score +
#     current_dummy_speeches * speeches_Sentiword_Score + post_dummy_speeches *
#     speeches_Sentiword_Score, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.028976 -0.001199  0.001041  0.003263  0.009816
#
# Coefficients: (2 not defined because of singularities)
#                                                  Estimate Std. Error t value
# (Intercept)                                     -0.003934   0.003654  -1.076
# prior_dummy_speeches                            -0.002887   0.011150  -0.259
# current_dummy_speeches                                 NA         NA      NA
# post_dummy_speeches                              0.001800   0.015749   0.114
# speeches_Sentiword_Score                         0.015751   0.010989   1.433
# ...

# %%
lm.BSE_V2_speeches_Hu...Liu.Polarity = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          current_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          post_dummy_speeches*speeches_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Hu...Liu.Polarity +
#     current_dummy_speeches * speeches_Hu...Liu.Polarity + post_dummy_speeches *
#     speeches_Hu...Liu.Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0293257 -0.0005956  0.0014679  0.0026319  0.0100790
#
# Coefficients: (2 not defined because of singularities)
#                                                    Estimate Std. Error t value
# (Intercept)                                       -0.001778   0.003433  -0.518
# prior_dummy_speeches                              -0.003159   0.008889  -0.355
# current_dummy_speeches                                   NA         NA      NA
# post_dummy_speeches                               -0.004697   0.030240  -0.155
# speeches_Hu...Liu.Polarity                         0.006399   0.007457   0.858
# ...

# %%
lm.BSE_V2_speeches_Loughran_Uncertainty = lm(BSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          current_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          post_dummy_speeches*speeches_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.BSE_V2_speeches_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Uncertainty +
#     current_dummy_speeches * speeches_Loughran_Uncertainty +
#     post_dummy_speeches * speeches_Loughran_Uncertainty, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0298365 -0.0006025  0.0011630  0.0030888  0.0100798
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                           0.0025348  0.0039427
# prior_dummy_speeches                                  0.0002753  0.0134855
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                   0.0050625  0.0112387
# speeches_Loughran_Uncertainty                        -0.2568511  0.5699515
# ...

# %%
lm.NSE_V1_speeches_Loughran_Polarity = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Polarity + 
                                          current_dummy_speeches*speeches_Loughran_Polarity + 
                                          post_dummy_speeches*speeches_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_Loughran_Polarity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Polarity +
#     current_dummy_speeches * speeches_Loughran_Polarity + post_dummy_speeches *
#     speeches_Loughran_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0223156 -0.0048751  0.0008302  0.0060199  0.0139660
#
# Coefficients: (2 not defined because of singularities)
#                                                     Estimate Std. Error t value
# (Intercept)                                       -0.0030515  0.0015938  -1.915
# prior_dummy_speeches                               0.0099758  0.0053256   1.873
# current_dummy_speeches                                    NA         NA      NA
# post_dummy_speeches                                0.0017444  0.0064065   0.272
# speeches_Loughran_Polarity                        -0.0004518  0.0052503  -0.086
# ...

# %%
lm.NSE_V1_speeches_Loughran_Subjectivity = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          current_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          post_dummy_speeches*speeches_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Subjectivity +
#     current_dummy_speeches * speeches_Loughran_Subjectivity +
#     post_dummy_speeches * speeches_Loughran_Subjectivity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0220489 -0.0056096  0.0005359  0.0057825  0.0131794
#
# Coefficients: (2 not defined because of singularities)
#                                                         Estimate Std. Error
# (Intercept)                                            0.0014242  0.0067934
# prior_dummy_speeches                                  -0.0726536  0.0693626
# current_dummy_speeches                                        NA         NA
# post_dummy_speeches                                   -0.0008986  0.0369733
# speeches_Loughran_Subjectivity                        -0.0507488  0.0748146
# ...

# %%
lm.NSE_V1_speeches_NRC_Polarity = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_NRC_Polarity + 
                                          current_dummy_speeches*speeches_NRC_Polarity + 
                                          post_dummy_speeches*speeches_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_NRC_Polarity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_NRC_Polarity +
#     current_dummy_speeches * speeches_NRC_Polarity + post_dummy_speeches *
#     speeches_NRC_Polarity, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.020994 -0.005067  0.000663  0.006599  0.013616
#
# Coefficients: (2 not defined because of singularities)
#                                               Estimate Std. Error t value
# (Intercept)                                  -0.005349   0.005678  -0.942
# prior_dummy_speeches                          0.009876   0.020472   0.482
# current_dummy_speeches                              NA         NA      NA
# post_dummy_speeches                          -0.002720   0.016074  -0.169
# speeches_NRC_Polarity                         0.005292   0.012560   0.421
# prior_dummy_speeches:speeches_NRC_Polarity    0.003216   0.064650   0.050
# ...

# %%
lm.NSE_V1_speeches_Financial_Stab_Score = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Financial_Stab_Score + 
                                          current_dummy_speeches*speeches_Financial_Stab_Score + 
                                          post_dummy_speeches*speeches_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Financial_Stab_Score +
#     current_dummy_speeches * speeches_Financial_Stab_Score +
#     post_dummy_speeches * speeches_Financial_Stab_Score, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0199280 -0.0045956 -0.0001285  0.0054228  0.0122278
#
# Coefficients: (2 not defined because of singularities)
#                                                       Estimate Std. Error
# (Intercept)                                          -0.004199   0.001658
# prior_dummy_speeches                                  0.011483   0.005021
# current_dummy_speeches                                      NA         NA
# post_dummy_speeches                                  -0.007421   0.006175
# speeches_Financial_Stab_Score                         0.006914   0.004218
# ...

# %%
lm.NSE_V1_speeches_Sentiword_Score = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Sentiword_Score + 
                                          current_dummy_speeches*speeches_Sentiword_Score + 
                                          post_dummy_speeches*speeches_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_Sentiword_Score)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Sentiword_Score +
#     current_dummy_speeches * speeches_Sentiword_Score + post_dummy_speeches *
#     speeches_Sentiword_Score, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0218456 -0.0048658  0.0009417  0.0067548  0.0142854
#
# Coefficients: (2 not defined because of singularities)
#                                                  Estimate Std. Error t value
# (Intercept)                                     -0.005030   0.004113  -1.223
# prior_dummy_speeches                             0.004408   0.012548   0.351
# current_dummy_speeches                                 NA         NA      NA
# post_dummy_speeches                              0.005436   0.017724   0.307
# speeches_Sentiword_Score                         0.006447   0.012367   0.521
# ...

# %%
lm.NSE_V1_speeches_Hu...Liu.Polarity = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          current_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          post_dummy_speeches*speeches_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Hu...Liu.Polarity +
#     current_dummy_speeches * speeches_Hu...Liu.Polarity + post_dummy_speeches *
#     speeches_Hu...Liu.Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0219149 -0.0048833  0.0001885  0.0069105  0.0129581
#
# Coefficients: (2 not defined because of singularities)
#                                                    Estimate Std. Error t value
# (Intercept)                                       -0.004773   0.003798  -1.257
# prior_dummy_speeches                               0.009399   0.009833   0.956
# current_dummy_speeches                                   NA         NA      NA
# post_dummy_speeches                                0.015050   0.033453   0.450
# speeches_Hu...Liu.Polarity                         0.004120   0.008250   0.499
# ...

# %%
lm.NSE_V1_speeches_Loughran_Uncertainty = lm(NSE_V1 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          current_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          post_dummy_speeches*speeches_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.NSE_V1_speeches_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Uncertainty +
#     current_dummy_speeches * speeches_Loughran_Uncertainty +
#     post_dummy_speeches * speeches_Loughran_Uncertainty, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0222352 -0.0048500  0.0006752  0.0066024  0.0138531
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                          -0.0020690  0.0043133
# prior_dummy_speeches                                  0.0008356  0.0147532
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                  -0.0072228  0.0122951
# speeches_Loughran_Uncertainty                        -0.1540319  0.6235273
# ...

# %%
lm.NSE_V2_speeches_Loughran_Polarity = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Polarity + 
                                          current_dummy_speeches*speeches_Loughran_Polarity + 
                                          post_dummy_speeches*speeches_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_Loughran_Polarity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Polarity +
#     current_dummy_speeches * speeches_Loughran_Polarity + post_dummy_speeches *
#     speeches_Loughran_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0296986 -0.0005906  0.0011131  0.0030465  0.0151741
#
# Coefficients: (2 not defined because of singularities)
#                                                     Estimate Std. Error t value
# (Intercept)                                        0.0001595  0.0016542   0.096
# prior_dummy_speeches                              -0.0010718  0.0055273  -0.194
# current_dummy_speeches                                    NA         NA      NA
# post_dummy_speeches                                0.0047385  0.0066491   0.713
# speeches_Loughran_Polarity                         0.0083585  0.0054491   1.534
# ...

# %%
lm.NSE_V2_speeches_Loughran_Subjectivity = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          current_dummy_speeches*speeches_Loughran_Subjectivity + 
                                          post_dummy_speeches*speeches_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Subjectivity +
#     current_dummy_speeches * speeches_Loughran_Subjectivity +
#     post_dummy_speeches * speeches_Loughran_Subjectivity, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.033330 -0.000526  0.001089  0.003856  0.011256
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                            0.002234   0.007349
# prior_dummy_speeches                                  -0.059482   0.075035
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                   -0.007354   0.039997
# speeches_Loughran_Subjectivity                        -0.022395   0.080933
# ...

# %%
lm.NSE_V2_speeches_NRC_Polarity = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_NRC_Polarity + 
                                          current_dummy_speeches*speeches_NRC_Polarity + 
                                          post_dummy_speeches*speeches_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_NRC_Polarity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_NRC_Polarity +
#     current_dummy_speeches * speeches_NRC_Polarity + post_dummy_speeches *
#     speeches_NRC_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0276050 -0.0020187  0.0007625  0.0030505  0.0164990
#
# Coefficients: (2 not defined because of singularities)
#                                               Estimate Std. Error t value
# (Intercept)                                  -0.011483   0.005556  -2.067
# prior_dummy_speeches                         -0.002677   0.020032  -0.134
# current_dummy_speeches                              NA         NA      NA
# post_dummy_speeches                           0.009744   0.015728   0.620
# speeches_NRC_Polarity                         0.027104   0.012290   2.205
# prior_dummy_speeches:speeches_NRC_Polarity    0.014892   0.063258   0.235
# ...

# %%
lm.NSE_V2_speeches_Financial_Stab_Score = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Financial_Stab_Score + 
                                          current_dummy_speeches*speeches_Financial_Stab_Score + 
                                          post_dummy_speeches*speeches_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Financial_Stab_Score +
#     current_dummy_speeches * speeches_Financial_Stab_Score +
#     post_dummy_speeches * speeches_Financial_Stab_Score, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.031873 -0.001179  0.001642  0.003371  0.013466
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                          -0.0005190  0.0018580
# prior_dummy_speeches                                 -0.0004752  0.0056275
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                   0.0011240  0.0069204
# speeches_Financial_Stab_Score                         0.0046954  0.0047273
# ...

# %%
lm.NSE_V2_speeches_Sentiword_Score = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Sentiword_Score + 
                                          current_dummy_speeches*speeches_Sentiword_Score + 
                                          post_dummy_speeches*speeches_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_Sentiword_Score)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Sentiword_Score +
#     current_dummy_speeches * speeches_Sentiword_Score + post_dummy_speeches *
#     speeches_Sentiword_Score, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.032561 -0.001201  0.001685  0.003685  0.011380
#
# Coefficients: (2 not defined because of singularities)
#                                                  Estimate Std. Error t value
# (Intercept)                                     -0.005539   0.004236  -1.308
# prior_dummy_speeches                            -0.004636   0.012923  -0.359
# current_dummy_speeches                                 NA         NA      NA
# post_dummy_speeches                              0.005954   0.018253   0.326
# speeches_Sentiword_Score                         0.018935   0.012736   1.487
# ...

# %%
lm.NSE_V2_speeches_Hu...Liu.Polarity = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          current_dummy_speeches*speeches_Hu...Liu.Polarity + 
                                          post_dummy_speeches*speeches_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Hu...Liu.Polarity +
#     current_dummy_speeches * speeches_Hu...Liu.Polarity + post_dummy_speeches *
#     speeches_Hu...Liu.Polarity, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.032983 -0.001117  0.001503  0.003591  0.011695
#
# Coefficients: (2 not defined because of singularities)
#                                                    Estimate Std. Error t value
# (Intercept)                                       -0.002936   0.003989  -0.736
# prior_dummy_speeches                              -0.004084   0.010328  -0.395
# current_dummy_speeches                                   NA         NA      NA
# post_dummy_speeches                                0.002415   0.035138   0.069
# speeches_Hu...Liu.Polarity                         0.007665   0.008665   0.885
# ...

# %%
lm.NSE_V2_speeches_Loughran_Uncertainty = lm(NSE_V2 ~ prior_dummy_speeches + 
                                          current_dummy_speeches + 
                                          post_dummy_speeches +
                                          prior_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          current_dummy_speeches*speeches_Loughran_Uncertainty + 
                                          post_dummy_speeches*speeches_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.NSE_V2_speeches_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_speeches + current_dummy_speeches +
#     post_dummy_speeches + prior_dummy_speeches * speeches_Loughran_Uncertainty +
#     current_dummy_speeches * speeches_Loughran_Uncertainty +
#     post_dummy_speeches * speeches_Loughran_Uncertainty, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.033547 -0.000549  0.001247  0.004359  0.011605
#
# Coefficients: (2 not defined because of singularities)
#                                                        Estimate Std. Error
# (Intercept)                                           0.0018302  0.0046058
# prior_dummy_speeches                                  0.0009321  0.0157536
# current_dummy_speeches                                       NA         NA
# post_dummy_speeches                                   0.0026213  0.0131288
# speeches_Loughran_Uncertainty                        -0.2454040  0.6658085
# ...

# %%
lm.BSE_V1_mpc_Loughran_Polarity = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Polarity + 
                                          current_dummy_mpc*mpc_Loughran_Polarity + 
                                          post_dummy_mpc*mpc_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_Loughran_Polarity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Polarity + current_dummy_mpc *
#     mpc_Loughran_Polarity + post_dummy_mpc * mpc_Loughran_Polarity,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.027131 -0.002357  0.001290  0.005494  0.017492
#
# Coefficients: (2 not defined because of singularities)
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -0.0032491  0.0048981  -0.663    0.511
# prior_dummy_mpc                         -0.0006239  0.0103311  -0.060    0.952
# current_dummy_mpc                               NA         NA      NA       NA
# post_dummy_mpc                          -0.0032255  0.0136136  -0.237    0.814
# mpc_Loughran_Polarity                   -0.0001154  0.0118031  -0.010    0.992
# prior_dummy_mpc:mpc_Loughran_Polarity   -0.0195565  0.0264811  -0.739    0.465
# ...

# %%
lm.BSE_V1_mpc_Loughran_Subjectivity = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          current_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          post_dummy_mpc*mpc_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Subjectivity + current_dummy_mpc *
#     mpc_Loughran_Subjectivity + post_dummy_mpc * mpc_Loughran_Subjectivity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0268573 -0.0029939  0.0002407  0.0052731  0.0175474
#
# Coefficients: (2 not defined because of singularities)
#                                              Estimate Std. Error t value
# (Intercept)                                 -0.001258   0.012478  -0.101
# prior_dummy_mpc                             -0.038221   0.042750  -0.894
# current_dummy_mpc                                  NA         NA      NA
# post_dummy_mpc                               0.012014   0.022492   0.534
# mpc_Loughran_Subjectivity                   -0.023220   0.155530  -0.149
# prior_dummy_mpc:mpc_Loughran_Subjectivity    0.616159   0.588104   1.048
# ...

# %%
lm.BSE_V1_mpc_NRC_Polarity = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_NRC_Polarity + 
                                          current_dummy_mpc*mpc_NRC_Polarity + 
                                          post_dummy_mpc*mpc_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_NRC_Polarity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_NRC_Polarity + current_dummy_mpc *
#     mpc_NRC_Polarity + post_dummy_mpc * mpc_NRC_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0271423 -0.0035299  0.0005467  0.0048822  0.0162334
#
# Coefficients: (2 not defined because of singularities)
#                                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)                        -0.0002436  0.0050131  -0.049    0.961
# prior_dummy_mpc                     0.0069305  0.0116691   0.594    0.556
# current_dummy_mpc                          NA         NA      NA       NA
# post_dummy_mpc                     -0.0139285  0.0116873  -1.192    0.241
# mpc_NRC_Polarity                   -0.0121610  0.0185488  -0.656    0.516
# prior_dummy_mpc:mpc_NRC_Polarity   -0.0040002  0.0456721  -0.088    0.931
# ...

# %%
lm.BSE_V1_mpc_Financial_Stab_Score = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Financial_Stab_Score + 
                                          current_dummy_mpc*mpc_Financial_Stab_Score + 
                                          post_dummy_mpc*mpc_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Financial_Stab_Score + current_dummy_mpc *
#     mpc_Financial_Stab_Score + post_dummy_mpc * mpc_Financial_Stab_Score,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0270778 -0.0028653  0.0007041  0.0055945  0.0175417
#
# Coefficients: (2 not defined because of singularities)
#                                              Estimate Std. Error t value
# (Intercept)                                -0.0033231  0.0021537  -1.543
# prior_dummy_mpc                             0.0041047  0.0047743   0.860
# current_dummy_mpc                                  NA         NA      NA
# post_dummy_mpc                              0.0048111  0.0046078   1.044
# mpc_Financial_Stab_Score                   -0.0002714  0.0094444  -0.029
# prior_dummy_mpc:mpc_Financial_Stab_Score   -0.0140100  0.0207589  -0.675
# ...

# %%
lm.BSE_V1_mpc_Sentiword_Score = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Sentiword_Score + 
                                          current_dummy_mpc*mpc_Sentiword_Score + 
                                          post_dummy_mpc*mpc_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_Sentiword_Score)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Sentiword_Score + current_dummy_mpc *
#     mpc_Sentiword_Score + post_dummy_mpc * mpc_Sentiword_Score,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0270965 -0.0024326 -0.0005039  0.0054871  0.0172412
#
# Coefficients: (2 not defined because of singularities)
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                           -0.002244   0.004114  -0.545    0.589
# prior_dummy_mpc                        0.006165   0.009549   0.646    0.522
# current_dummy_mpc                            NA         NA      NA       NA
# post_dummy_mpc                        -0.009069   0.010492  -0.864    0.393
# mpc_Sentiword_Score                   -0.008388   0.029287  -0.286    0.776
# prior_dummy_mpc:mpc_Sentiword_Score    0.002234   0.061119   0.037    0.971
# ...

# %%
lm.BSE_V1_mpc_Hu...Liu.Polarity = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          current_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          post_dummy_mpc*mpc_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Hu...Liu.Polarity + current_dummy_mpc *
#     mpc_Hu...Liu.Polarity + post_dummy_mpc * mpc_Hu...Liu.Polarity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0274731 -0.0032976  0.0002853  0.0049772  0.0162443
#
# Coefficients: (2 not defined because of singularities)
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -0.002291   0.002155  -1.063   0.2945
# prior_dummy_mpc                          0.008625   0.005083   1.697   0.0979 .
# current_dummy_mpc                              NA         NA      NA       NA
# post_dummy_mpc                          -0.003726   0.004974  -0.749   0.4585
# mpc_Hu...Liu.Polarity                   -0.008092   0.010848  -0.746   0.4603
# prior_dummy_mpc:mpc_Hu...Liu.Polarity   -0.019908   0.026983  -0.738   0.4652
# ...

# %%
lm.BSE_V1_mpc_Loughran_Uncertainty = lm(BSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          current_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          post_dummy_mpc*mpc_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.BSE_V1_mpc_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = BSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Uncertainty + current_dummy_mpc *
#     mpc_Loughran_Uncertainty + post_dummy_mpc * mpc_Loughran_Uncertainty,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0269248 -0.0026380  0.0007109  0.0053815  0.0176452
#
# Coefficients: (2 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                                -0.003706   0.006056  -0.612
# prior_dummy_mpc                             0.010349   0.014140   0.732
# current_dummy_mpc                                 NA         NA      NA
# post_dummy_mpc                              0.002029   0.017534   0.116
# mpc_Loughran_Uncertainty                    0.063835   1.005000   0.064
# prior_dummy_mpc:mpc_Loughran_Uncertainty   -1.055279   3.507711  -0.301
# ...

# %%
lm.BSE_V2_mpc_Loughran_Polarity = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Polarity + 
                                          current_dummy_mpc*mpc_Loughran_Polarity + 
                                          post_dummy_mpc*mpc_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_Loughran_Polarity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Polarity + current_dummy_mpc *
#     mpc_Loughran_Polarity + post_dummy_mpc * mpc_Loughran_Polarity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0128958 -0.0034817 -0.0002677  0.0019002  0.0294786
#
# Coefficients: (2 not defined because of singularities)
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -0.0002039  0.0039813  -0.051    0.959
# prior_dummy_mpc                         -0.0056860  0.0083973  -0.677    0.502
# current_dummy_mpc                               NA         NA      NA       NA
# post_dummy_mpc                           0.0017876  0.0110655   0.162    0.873
# mpc_Loughran_Polarity                   -0.0099125  0.0095939  -1.033    0.308
# ...

# %%
lm.BSE_V2_mpc_Loughran_Subjectivity = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          current_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          post_dummy_mpc*mpc_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Subjectivity + current_dummy_mpc *
#     mpc_Loughran_Subjectivity + post_dummy_mpc * mpc_Loughran_Subjectivity,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.012140 -0.003705 -0.001259  0.002242  0.025823
#
# Coefficients: (2 not defined because of singularities)
#                                              Estimate Std. Error t value
# (Intercept)                                 -0.016259   0.010082  -1.613
# prior_dummy_mpc                             -0.009281   0.034540  -0.269
# current_dummy_mpc                                  NA         NA      NA
# post_dummy_mpc                               0.014637   0.018172   0.805
# mpc_Loughran_Subjectivity                    0.250328   0.125661   1.992
# prior_dummy_mpc:mpc_Loughran_Subjectivity    0.172547   0.475162   0.363
# ...

# %%
lm.BSE_V2_mpc_NRC_Polarity = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_NRC_Polarity + 
                                          current_dummy_mpc*mpc_NRC_Polarity + 
                                          post_dummy_mpc*mpc_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_NRC_Polarity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_NRC_Polarity + current_dummy_mpc *
#     mpc_NRC_Polarity + post_dummy_mpc * mpc_NRC_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0113296 -0.0032800 -0.0012082  0.0007396  0.0308853
#
# Coefficients: (2 not defined because of singularities)
#                                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)                         0.001781   0.004251   0.419    0.678
# prior_dummy_mpc                     0.010993   0.009895   1.111    0.274
# current_dummy_mpc                         NA         NA      NA       NA
# post_dummy_mpc                     -0.002072   0.009911  -0.209    0.836
# mpc_NRC_Polarity                    0.006356   0.015729   0.404    0.688
# prior_dummy_mpc:mpc_NRC_Polarity   -0.040508   0.038730  -1.046    0.302
# ...

# %%
lm.BSE_V2_mpc_Financial_Stab_Score = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Financial_Stab_Score + 
                                          current_dummy_mpc*mpc_Financial_Stab_Score + 
                                          post_dummy_mpc*mpc_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Financial_Stab_Score + current_dummy_mpc *
#     mpc_Financial_Stab_Score + post_dummy_mpc * mpc_Financial_Stab_Score,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.012094 -0.002759 -0.001044  0.001404  0.030898
#
# Coefficients: (2 not defined because of singularities)
#                                              Estimate Std. Error t value
# (Intercept)                                 0.0033409  0.0018093   1.847
# prior_dummy_mpc                            -0.0020924  0.0040108  -0.522
# current_dummy_mpc                                  NA         NA      NA
# post_dummy_mpc                             -0.0005961  0.0038709  -0.154
# mpc_Financial_Stab_Score                   -0.0010230  0.0079341  -0.129
# prior_dummy_mpc:mpc_Financial_Stab_Score   -0.0215503  0.0174393  -1.236
# ...

# %%
lm.BSE_V2_mpc_Sentiword_Score = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Sentiword_Score + 
                                          current_dummy_mpc*mpc_Sentiword_Score + 
                                          post_dummy_mpc*mpc_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_Sentiword_Score)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Sentiword_Score + current_dummy_mpc *
#     mpc_Sentiword_Score + post_dummy_mpc * mpc_Sentiword_Score,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.011130 -0.003235 -0.001435  0.001349  0.031072
#
# Coefficients: (2 not defined because of singularities)
#                                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)                            0.0017934  0.0034295   0.523    0.604
# prior_dummy_mpc                        0.0107992  0.0079603   1.357    0.183
# current_dummy_mpc                             NA         NA      NA       NA
# post_dummy_mpc                         0.0005999  0.0087462   0.069    0.946
# mpc_Sentiword_Score                    0.0127839  0.0244144   0.524    0.604
# prior_dummy_mpc:mpc_Sentiword_Score   -0.0669650  0.0509509  -1.314    0.197
# ...

# %%
lm.BSE_V2_mpc_Hu...Liu.Polarity = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          current_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          post_dummy_mpc*mpc_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Hu...Liu.Polarity + current_dummy_mpc *
#     mpc_Hu...Liu.Polarity + post_dummy_mpc * mpc_Hu...Liu.Polarity,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.011380 -0.003016 -0.001291  0.001571  0.031174
#
# Coefficients: (2 not defined because of singularities)
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                              0.0029630  0.0018059   1.641   0.1091
# prior_dummy_mpc                          0.0069061  0.0042596   1.621   0.1132
# current_dummy_mpc                               NA         NA      NA       NA
# post_dummy_mpc                          -0.0005416  0.0041685  -0.130   0.8973
# mpc_Hu...Liu.Polarity                    0.0037549  0.0090907   0.413   0.6819
# prior_dummy_mpc:mpc_Hu...Liu.Polarity   -0.0437395  0.0226115  -1.934   0.0605
# ...

# %%
lm.BSE_V2_mpc_Loughran_Uncertainty = lm(BSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          current_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          post_dummy_mpc*mpc_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.BSE_V2_mpc_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = BSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Uncertainty + current_dummy_mpc *
#     mpc_Loughran_Uncertainty + post_dummy_mpc * mpc_Loughran_Uncertainty,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.012475 -0.003438 -0.001026  0.001708  0.029308
#
# Coefficients: (2 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                                 0.009085   0.004933   1.841
# prior_dummy_mpc                             0.004188   0.011520   0.364
# current_dummy_mpc                                 NA         NA      NA
# post_dummy_mpc                             -0.008882   0.014285  -0.622
# mpc_Loughran_Uncertainty                   -0.992729   0.818762  -1.212
# prior_dummy_mpc:mpc_Loughran_Uncertainty   -1.337621   2.857691  -0.468
# ...

# %%
lm.NSE_V1_mpc_Loughran_Polarity = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Polarity + 
                                          current_dummy_mpc*mpc_Loughran_Polarity + 
                                          post_dummy_mpc*mpc_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_Loughran_Polarity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Polarity + current_dummy_mpc *
#     mpc_Loughran_Polarity + post_dummy_mpc * mpc_Loughran_Polarity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0289074 -0.0028816  0.0008502  0.0047225  0.0187088
#
# Coefficients: (2 not defined because of singularities)
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -0.0025969  0.0048551  -0.535    0.596
# prior_dummy_mpc                         -0.0007612  0.0102405  -0.074    0.941
# current_dummy_mpc                               NA         NA      NA       NA
# post_dummy_mpc                          -0.0014839  0.0134943  -0.110    0.913
# mpc_Loughran_Polarity                    0.0014401  0.0116997   0.123    0.903
# ...

# %%
lm.NSE_V1_mpc_Loughran_Subjectivity = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          current_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          post_dummy_mpc*mpc_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Subjectivity + current_dummy_mpc *
#     mpc_Loughran_Subjectivity + post_dummy_mpc * mpc_Loughran_Subjectivity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0284913 -0.0029059  0.0007642  0.0047569  0.0186225
#
# Coefficients: (2 not defined because of singularities)
#                                               Estimate Std. Error t value
# (Intercept)                                  0.0006266  0.0123989   0.051
# prior_dummy_mpc                             -0.0332236  0.0424777  -0.782
# current_dummy_mpc                                   NA         NA      NA
# post_dummy_mpc                               0.0090578  0.0223486   0.405
# mpc_Loughran_Subjectivity                   -0.0465040  0.1545389  -0.301
# prior_dummy_mpc:mpc_Loughran_Subjectivity    0.5271315  0.5843575   0.902
# ...

# %%
lm.NSE_V1_mpc_NRC_Polarity = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_NRC_Polarity + 
                                          current_dummy_mpc*mpc_NRC_Polarity + 
                                          post_dummy_mpc*mpc_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_NRC_Polarity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_NRC_Polarity + current_dummy_mpc *
#     mpc_NRC_Polarity + post_dummy_mpc * mpc_NRC_Polarity, data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0291197 -0.0041797  0.0006894  0.0059477  0.0174798
#
# Coefficients: (2 not defined because of singularities)
#                                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)                        -0.0009077  0.0049908  -0.182    0.857
# prior_dummy_mpc                     0.0072562  0.0116172   0.625    0.536
# current_dummy_mpc                          NA         NA      NA       NA
# post_dummy_mpc                     -0.0092422  0.0116352  -0.794    0.432
# mpc_NRC_Polarity                   -0.0093294  0.0184663  -0.505    0.616
# prior_dummy_mpc:mpc_NRC_Polarity   -0.0102005  0.0454688  -0.224    0.824
# ...

# %%
lm.NSE_V1_mpc_Financial_Stab_Score = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Financial_Stab_Score + 
                                          current_dummy_mpc*mpc_Financial_Stab_Score + 
                                          post_dummy_mpc*mpc_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Financial_Stab_Score + current_dummy_mpc *
#     mpc_Financial_Stab_Score + post_dummy_mpc * mpc_Financial_Stab_Score,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.028727 -0.002848  0.000323  0.004754  0.018890
#
# Coefficients: (2 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                                -0.002944   0.002138  -1.377
# prior_dummy_mpc                             0.002815   0.004738   0.594
# current_dummy_mpc                                 NA         NA      NA
# post_dummy_mpc                              0.005564   0.004573   1.217
# mpc_Financial_Stab_Score                    0.001989   0.009374   0.212
# prior_dummy_mpc:mpc_Financial_Stab_Score   -0.014726   0.020603  -0.715
# ...

# %%
lm.NSE_V1_mpc_Sentiword_Score = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Sentiword_Score + 
                                          current_dummy_mpc*mpc_Sentiword_Score + 
                                          post_dummy_mpc*mpc_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_Sentiword_Score)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Sentiword_Score + current_dummy_mpc *
#     mpc_Sentiword_Score + post_dummy_mpc * mpc_Sentiword_Score,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0290655 -0.0041584  0.0005455  0.0049941  0.0183914
#
# Coefficients: (2 not defined because of singularities)
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                           -0.002864   0.004092  -0.700    0.488
# prior_dummy_mpc                        0.006036   0.009498   0.635    0.529
# current_dummy_mpc                            NA         NA      NA       NA
# post_dummy_mpc                        -0.004308   0.010436  -0.413    0.682
# mpc_Sentiword_Score                   -0.002977   0.029132  -0.102    0.919
# prior_dummy_mpc:mpc_Sentiword_Score   -0.005881   0.060796  -0.097    0.923
# ...

# %%
lm.NSE_V1_mpc_Hu...Liu.Polarity = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          current_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          post_dummy_mpc*mpc_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Hu...Liu.Polarity + current_dummy_mpc *
#     mpc_Hu...Liu.Polarity + post_dummy_mpc * mpc_Hu...Liu.Polarity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0294282 -0.0032204  0.0006466  0.0053868  0.0173664
#
# Coefficients: (2 not defined because of singularities)
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -0.002383   0.002154  -1.106    0.276
# prior_dummy_mpc                          0.007177   0.005080   1.413    0.166
# current_dummy_mpc                              NA         NA      NA       NA
# post_dummy_mpc                          -0.001471   0.004971  -0.296    0.769
# mpc_Hu...Liu.Polarity                   -0.006805   0.010842  -0.628    0.534
# prior_dummy_mpc:mpc_Hu...Liu.Polarity   -0.017913   0.026966  -0.664    0.511
# ...

# %%
lm.NSE_V1_mpc_Loughran_Uncertainty = lm(NSE_V1 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          current_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          post_dummy_mpc*mpc_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.NSE_V1_mpc_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = NSE_V1 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Uncertainty + current_dummy_mpc *
#     mpc_Loughran_Uncertainty + post_dummy_mpc * mpc_Loughran_Uncertainty,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0289130 -0.0033824  0.0006993  0.0045436  0.0185654
#
# Coefficients: (2 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                                -0.003807   0.005974  -0.637
# prior_dummy_mpc                             0.010074   0.013951   0.722
# current_dummy_mpc                                 NA         NA      NA
# post_dummy_mpc                              0.002938   0.017299   0.170
# mpc_Loughran_Uncertainty                    0.090431   0.991533   0.091
# prior_dummy_mpc:mpc_Loughran_Uncertainty   -1.292837   3.460708  -0.374
# ...

# %%
lm.NSE_V2_mpc_Loughran_Polarity = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Polarity + 
                                          current_dummy_mpc*mpc_Loughran_Polarity + 
                                          post_dummy_mpc*mpc_Loughran_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_Loughran_Polarity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Polarity + current_dummy_mpc *
#     mpc_Loughran_Polarity + post_dummy_mpc * mpc_Loughran_Polarity,
#     data = bsensedata)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0149717 -0.0044070  0.0000671  0.0026180  0.0312893
#
# Coefficients: (2 not defined because of singularities)
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                             -0.001448   0.004607  -0.314    0.755
# prior_dummy_mpc                         -0.004642   0.009717  -0.478    0.636
# current_dummy_mpc                              NA         NA      NA       NA
# post_dummy_mpc                           0.002086   0.012805   0.163    0.871
# mpc_Loughran_Polarity                   -0.013284   0.011102  -1.197    0.239
# prior_dummy_mpc:mpc_Loughran_Polarity   -0.020304   0.024907  -0.815    0.420
# ...

# %%
lm.NSE_V2_mpc_Loughran_Subjectivity = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          current_dummy_mpc*mpc_Loughran_Subjectivity + 
                                          post_dummy_mpc*mpc_Loughran_Subjectivity , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_Loughran_Subjectivity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Subjectivity + current_dummy_mpc *
#     mpc_Loughran_Subjectivity + post_dummy_mpc * mpc_Loughran_Subjectivity,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.014499 -0.004475 -0.001116  0.002406  0.027143
#
# Coefficients: (2 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                                 -0.02082    0.01161  -1.793
# prior_dummy_mpc                             -0.00847    0.03978  -0.213
# current_dummy_mpc                                 NA         NA      NA
# post_dummy_mpc                               0.01911    0.02093   0.913
# mpc_Loughran_Subjectivity                    0.30855    0.14474   2.132
# prior_dummy_mpc:mpc_Loughran_Subjectivity    0.17905    0.54730   0.327
# ...

# %%
lm.NSE_V2_mpc_NRC_Polarity = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_NRC_Polarity + 
                                          current_dummy_mpc*mpc_NRC_Polarity + 
                                          post_dummy_mpc*mpc_NRC_Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_NRC_Polarity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_NRC_Polarity + current_dummy_mpc *
#     mpc_NRC_Polarity + post_dummy_mpc * mpc_NRC_Polarity, data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.014226 -0.003502 -0.001313  0.000818  0.033212
#
# Coefficients: (2 not defined because of singularities)
#                                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)                         0.002300   0.004941   0.465    0.644
# prior_dummy_mpc                     0.011703   0.011500   1.018    0.315
# current_dummy_mpc                         NA         NA      NA       NA
# post_dummy_mpc                     -0.004881   0.011518  -0.424    0.674
# mpc_NRC_Polarity                    0.004492   0.018280   0.246    0.807
# prior_dummy_mpc:mpc_NRC_Polarity   -0.040226   0.045011  -0.894    0.377
# ...

# %%
lm.NSE_V2_mpc_Financial_Stab_Score = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Financial_Stab_Score + 
                                          current_dummy_mpc*mpc_Financial_Stab_Score + 
                                          post_dummy_mpc*mpc_Financial_Stab_Score , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_Financial_Stab_Score)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Financial_Stab_Score + current_dummy_mpc *
#     mpc_Financial_Stab_Score + post_dummy_mpc * mpc_Financial_Stab_Score,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.014943 -0.003451 -0.001098  0.001672  0.032962
#
# Coefficients: (2 not defined because of singularities)
#                                              Estimate Std. Error t value
# (Intercept)                                 0.0029248  0.0021006   1.392
# prior_dummy_mpc                            -0.0010330  0.0046565  -0.222
# current_dummy_mpc                                  NA         NA      NA
# post_dummy_mpc                             -0.0008467  0.0044941  -0.188
# mpc_Financial_Stab_Score                   -0.0044090  0.0092115  -0.479
# prior_dummy_mpc:mpc_Financial_Stab_Score   -0.0196118  0.0202470  -0.969
# ...

# %%
lm.NSE_V2_mpc_Sentiword_Score = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Sentiword_Score + 
                                          current_dummy_mpc*mpc_Sentiword_Score + 
                                          post_dummy_mpc*mpc_Sentiword_Score , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_Sentiword_Score)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Sentiword_Score + current_dummy_mpc *
#     mpc_Sentiword_Score + post_dummy_mpc * mpc_Sentiword_Score,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.014140 -0.003365 -0.001595  0.001355  0.033336
#
# Coefficients: (2 not defined because of singularities)
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                            0.002375   0.003998   0.594    0.556
# prior_dummy_mpc                        0.011400   0.009279   1.229    0.227
# current_dummy_mpc                            NA         NA      NA       NA
# post_dummy_mpc                        -0.002072   0.010195  -0.203    0.840
# mpc_Sentiword_Score                    0.008562   0.028459   0.301    0.765
# prior_dummy_mpc:mpc_Sentiword_Score   -0.065022   0.059392  -1.095    0.280
# ...

# %%
lm.NSE_V2_mpc_Hu...Liu.Polarity = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          current_dummy_mpc*mpc_Hu...Liu.Polarity + 
                                          post_dummy_mpc*mpc_Hu...Liu.Polarity , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_Hu...Liu.Polarity)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Hu...Liu.Polarity + current_dummy_mpc *
#     mpc_Hu...Liu.Polarity + post_dummy_mpc * mpc_Hu...Liu.Polarity,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.014374 -0.003360 -0.001036  0.002037  0.033372
#
# Coefficients: (2 not defined because of singularities)
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                              0.003245   0.002108   1.539   0.1321
# prior_dummy_mpc                          0.007913   0.004973   1.591   0.1199
# current_dummy_mpc                              NA         NA      NA       NA
# post_dummy_mpc                          -0.001935   0.004867  -0.398   0.6932
# mpc_Hu...Liu.Polarity                    0.001856   0.010614   0.175   0.8621
# prior_dummy_mpc:mpc_Hu...Liu.Polarity   -0.045301   0.026400  -1.716   0.0943 .
# ...

# %%
lm.NSE_V2_mpc_Loughran_Uncertainty = lm(NSE_V2 ~ prior_dummy_mpc + 
                                          current_dummy_mpc + 
                                          post_dummy_mpc +
                                          prior_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          current_dummy_mpc*mpc_Loughran_Uncertainty + 
                                          post_dummy_mpc*mpc_Loughran_Uncertainty , 
                                          data = bsensedata)
summary(lm.NSE_V2_mpc_Loughran_Uncertainty)
# Out:
# Call:
# lm(formula = NSE_V2 ~ prior_dummy_mpc + current_dummy_mpc + post_dummy_mpc +
#     prior_dummy_mpc * mpc_Loughran_Uncertainty + current_dummy_mpc *
#     mpc_Loughran_Uncertainty + post_dummy_mpc * mpc_Loughran_Uncertainty,
#     data = bsensedata)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.015315 -0.003635 -0.001758  0.001427  0.031577
#
# Coefficients: (2 not defined because of singularities)
#                                             Estimate Std. Error t value
# (Intercept)                                 0.009167   0.005759   1.592
# prior_dummy_mpc                             0.005263   0.013448   0.391
# current_dummy_mpc                                 NA         NA      NA
# post_dummy_mpc                             -0.010065   0.016676  -0.604
# mpc_Loughran_Uncertainty                   -0.999496   0.955819  -1.046
# prior_dummy_mpc:mpc_Loughran_Uncertainty   -1.404596   3.336057  -0.421
# ...
